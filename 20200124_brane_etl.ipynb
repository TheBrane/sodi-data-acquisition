# %%
import pandas as pd
import numpy as np
import requests
import inflection as inf
from collections import OrderedDict

# %%
from nltk.corpus import wordnet as wn

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/dcomfort/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
pd.__version__
# Out:
# '0.25.3'

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Read raw data

# %%
df = pd.read_csv('data/ISS mandate - Raw data.csv')

# %%
test = df[['TI','DE','ID' , 'DI']].head(100)

# %%
test
# Out:
#                                                    TI  \
# 0   Two regimes of a single n-heptane droplet comb...
# 1   Desert cyanobacteria under space and planetary...
# 2   Photolysis of Cometary Organic Dust Analogs on...
# 3           Diffusive Motion in a 3-D Cluster in PK-4
# 4   Negative Effects of Long-duration Spaceflight ...
# ..                                                ...
# 95  CONTRIBUTION OF DIFFERENT PARTICLES MEASURED W...
# 96  Dust density waves in a dc flowing complex pla...
# 97  Capturing the Urban Divide in Nighttime Light ...
# 98  Space-Based Microgravity Experiments on Flame ...
# 99  Radiative extinction of large n-alkane droplet...
#
#                                                    DE  \
# 0   Combustion; Cool flame; Droplet; Mathematical ...
# 1   Chroococcidiopsis; desiccation tolerance; dese...
# 2   Astrobiology; Astrochemistry; Comets; Internat...
# 3   Diffusion; dusty plasma; microgravity; Plasmak...
# 4   aerospace medicine; atrophy; back pain; comput...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  Deprived areas; Global South; International Sp...
# 98  Flame spread; Droplet cloud; Group combustion;...
# 99  Droplet combustion; Radiative extinction; N-al...
#
#                                                    ID  \
# 0     DIFFUSION COMBUSTION; COOL-FLAMES; MICROGRAVITY
# 1   RADIATION-RESISTANCE; MARTIAN ATMOSPHERE; SYNT...
# 2   ULTRACARBONACEOUS ANTARCTIC MICROMETEORITES; I...
# 3   ANOMALOUS DIFFUSION; DUST PARTICLES; DYNAMICS;...
# 4   LOW-BACK-PAIN; FAT INFILTRATION; MECHANICAL-PR...
# ..                                                ...
# 95                               RADIATION; DOSIMETRY
# 96                                     ACOUSTIC-WAVES
# 97              SATELLITE IMAGERY; CHINA; SLUMS; DMSP
# 98  COMBUSTION EXPERIMENTS ABOARD; FUEL; ARRAYS; P...
# 99  SPHERICAL DIFFUSION FLAMES; COOL-FLAMES; COMBU...
#
#                                     DI
# 0      10.1016/j.actaastro.2019.01.045
# 1            10.1017/S147355041800037X
# 2                10.1089/ast.2018.1853
# 3             10.1109/TPS.2019.2893155
# 4         10.1097/BRS.0000000000002959
# ..                                 ...
# 95                  10.1093/rpd/ncx189
# 96                   10.1063/1.5040417
# 97         10.1109/JSTARS.2018.2828340
# 98           10.1007/s12217-018-9637-2
# 99  10.1016/j.combustflame.2018.04.023
#
# [100 rows x 4 columns]

# %%
test['DE'][0]
# Out:
# 'Combustion; Cool flame; Droplet; Mathematical modeling; Diffusion'

# %%
test['DE'] = test['DE'].str.replace('; ', ', ')
test['ID'] = test['ID'].str.replace('; ', ', ')

test['DE'] = test['DE'].str.replace('-', ' ')
test['ID'] = test['ID'].str.replace('-', ' ')

test['DE'] = test['DE'].fillna(' ')
test['ID'] = test['ID'].fillna(' ')

# %%
# 2. Combine keyword columns
test['keywords'] = test['DE'] + ', ' + test['ID']

# %%
# 3. lowercase keyword case
test['keywords'] = test['keywords'].str.lower()

test = test[['TI','keywords' , 'DI']]

# %%
# 4. singularize
# test['keywords'] = test['keywords'].apply(lambda x: ', '.join([inf.singularize(item) for item in x.split(', ')]))

# %%
# maybe lowercase afterwards
# POS tags - if noun don't singularize

# %%
# 5. Remove duplicates
# https://stackoverflow.com/questions/47316783/python-dataframe-remove-duplicate-words-in-the-same-cell-within-a-column-in-pyt
test['keywords'] = (test['keywords'].str.split(', ')
                              .apply(lambda x: OrderedDict.fromkeys(x).keys())
                              .str.join(', '))

# %%
# 6. Split strings
test['keywords'] = test['keywords'].str.split(', ', expand=False)

# %%
test['keywords'][0]
# Out:
# ['combustion',
#  'cool flame',
#  'droplet',
#  'mathematical modeling',
#  'diffusion',
#  'diffusion combustion',
#  'cool flames',
#  'microgravity']

# %%
test.shape[0]
# Out:
# 100

# %%
# 7. pandas explode - Transform each element of a list-like to a row, replicating the index values.
test_ = test.explode('keywords')

test_ = test_[test_['keywords'] != ' ']

test_.reset_index(inplace=True, drop=True)

# %%
test_['keywords'].nunique()
# Out:
# 842

# %%
test_['keywords']
# Out:
# 0                       combustion
# 1                       cool flame
# 2                          droplet
# 3            mathematical modeling
# 4                        diffusion
#                    ...
# 1121                  microgravity
# 1122    spherical diffusion flames
# 1123                   cool flames
# 1124                    combustion
# 1125                       heptane
# Name: keywords, Length: 1126, dtype: object

# %% [markdown]
# ___

# %% [markdown]
# # Extract from Wordnet

# %%
from nltk.corpus import wordnet
wn_lemmas = set(wordnet.all_lemma_names())

def wordnet_exits(word):
    word = word.replace(' ', '_')
    if word in wn_lemmas:
        return True
    else:
        return False

# %%
wordnet_exits('microgravity')
# Out:
# False

# %%
def acquire_definition(keyword):
    define = wn.synsets(keyword)[0].definition()
    return define

# %%
def acquire_hypernym(keyword):
    hypernym = wn.synsets(keyword)[0].hypernyms()[0].name().split(".")[0]
    return hypernym

# %%
def acquire_wordnet_id(keyword):
    synset = wn.synsets(keyword)[0].name()
    ss = wn.synset(synset)
    offset = str(ss.offset()).zfill(8) + '-' + ss.pos()
    return offset

# %%
acquire_wordnet_id('combustion')
# Out:
# '13450206-n'

# %%
test_.reset_index(drop=True, inplace=True)

# %%
test_.head()
# Out:
#                                                   TI               keywords  \
# 0  Two regimes of a single n-heptane droplet comb...             combustion
# 1  Two regimes of a single n-heptane droplet comb...             cool flame
# 2  Two regimes of a single n-heptane droplet comb...                droplet
# 3  Two regimes of a single n-heptane droplet comb...  mathematical modeling
# 4  Two regimes of a single n-heptane droplet comb...              diffusion
#
#                                 DI
# 0  10.1016/j.actaastro.2019.01.045
# 1  10.1016/j.actaastro.2019.01.045
# 2  10.1016/j.actaastro.2019.01.045
# 3  10.1016/j.actaastro.2019.01.045
# 4  10.1016/j.actaastro.2019.01.045

# %%
test_.shape[0]
# Out:
# 1126

# %%
df_test_ = test_.copy()

# %%
df_test_.rename(columns={'TI': 'topic_title', 'keywords': 'definition', 
                       'DI': 'reference' }, inplace=True)

# %%
df_test_[df_test_['definition'].str.contains('^mar$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [topic_title, definition, reference]
# Index: []

# %%
df_test_['definition'] = df_test_['definition'].str.replace('^mar$', 'mars', regex=True)

# %%
df_test_[df_test_['definition'].str.contains('^mars', regex=True)]
# Out:
#                                            topic_title            definition  \
# 13   Desert cyanobacteria under space and planetary...  mars like conditions
# 21   Desert cyanobacteria under space and planetary...                  mars
# 741  Survival, DNA, and Ultrastructural Integrity o...       mars conditions
#
#                      reference
# 13   10.1017/S147355041800037X
# 21   10.1017/S147355041800037X
# 741      10.1089/ast.2017.1728

# %%
# df_test_ = df_test_.head(10)

# %%
df_test_.shape[0]
# Out:
# 1126

# %%
data = []
j = 1
for index, row in df_test_.iterrows():
    print('index: ', index, 'keywords: ', row['definition'])
    if wordnet_exits(row['definition']):
        word = row['definition']
        word = word.replace(' ', '_')
        print('Word exists in WordNet')
        print('*****************')
        print('j: ', j)
        key = 'T' + str(j)
        print('initial key: ', key)

        data.append(dict(zip(
            ('key',
             'type', 
             'topic_title', 
             'definition', 
             'reference',
            'wordnet_ID'), 
            (key,
            'topic',
             row['topic_title'],
             word,  
             '',
           acquire_wordnet_id(word))
        )))
        j = j + 1
        print('j: ', j)
        key = 'T' + str(j)
        print('key: ', key)

        data.append(dict(zip(
            ('key',
             'type', 
             'topic_title', 
             'definition', 
             'reference',
            'wordnet_ID'), 
            (key,
            'topic',
             word,
             acquire_definition(word),  
             '',
            acquire_wordnet_id(word))
        )))
        
        try:
            hypernym = acquire_hypernym(word)
            j = j + 1
            print('j: ', j)
            key = 'T' + str(j)
            print('key: ', key)

            data.append(dict(zip(
                ('key',
                 'type', 
                 'topic_title', 
                 'definition', 
                 'reference',
                'wordnet_ID'), 
                (key,
                'cluster',
                 hypernym,
                 acquire_definition(hypernym),  
                 '',
                acquire_wordnet_id(hypernym))
            )))
        except:
            pass

        j = j + 1
        print('j: ', j)
        key = 'T' + str(j)
        print('key: ', key)
        # repeat for i >= 4 through 9
        i = 4
#         while i <=9:
#             try:
#                 hypernym = acquire_hypernym(hypernym)
#                 key = 'T' + str(j)
#                 print('j: ', j)
#                 key = 'T' + str(j)
#                 print('key: ', key)

#                 data.append(dict(zip(
#                     ('key',
#                      'type', 
#                      'topic_title', 
#                      'definition', 
#                      'reference',
#                 'wordnet_ID'), 
#                     (key,
#                     'cluster',
#                      hypernym,
#                      acquire_definition(hypernym),  
#                      '',
#                 '')
#                 )))
#             except:
#                 pass
#             i = i +1
#             j = j + 1

        df_topic = pd.DataFrame(data)
    
    else:
        print('Word DOES NOT exists in WordNet')
        print('*****************')
# Out:
# index:  0 keywords:  combustion
# Word exists in WordNet
# *****************
# j:  1
# initial key:  T1
# j:  2
# key:  T2
# j:  3
# key:  T3
# j:  4
# key:  T4
# index:  1 keywords:  cool flame
# Word DOES NOT exists in WordNet
# *****************
# index:  2 keywords:  droplet
# Word exists in WordNet
# *****************
# j:  4
# initial key:  T4
# j:  5
# key:  T5
# j:  6
# key:  T6
# j:  7
# key:  T7
# index:  3 keywords:  mathematical modeling
# Word DOES NOT exists in WordNet
# *****************
# index:  4 keywords:  diffusion
# Word exists in WordNet
# *****************
# j:  7
# initial key:  T7
# j:  8
# key:  T8
# j:  9
# key:  T9
# j:  10
# key:  T10
# index:  5 keywords:  diffusion combustion
# Word DOES NOT exists in WordNet
# *****************
# index:  6 keywords:  cool flames
# Word DOES NOT exists in WordNet
# *****************
# index:  7 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  8 keywords:  chroococcidiopsis
# Word DOES NOT exists in WordNet
# *****************
# index:  9 keywords:  desiccation tolerance
# Word DOES NOT exists in WordNet
# *****************
# index:  10 keywords:  desert cyanobacteria
# Word DOES NOT exists in WordNet
# *****************
# index:  11 keywords:  life support
# Word exists in WordNet
# *****************
# j:  10
# initial key:  T10
# j:  11
# key:  T11
# j:  12
# key:  T12
# j:  13
# key:  T13
# index:  12 keywords:  low earth orbit
# Word DOES NOT exists in WordNet
# *****************
# index:  13 keywords:  mars like conditions
# Word DOES NOT exists in WordNet
# *****************
# index:  14 keywords:  radiation tolerance
# Word DOES NOT exists in WordNet
# *****************
# index:  15 keywords:  space exposure
# Word DOES NOT exists in WordNet
# *****************
# index:  16 keywords:  space synthetic biology
# Word DOES NOT exists in WordNet
# *****************
# index:  17 keywords:  radiation resistance
# Word DOES NOT exists in WordNet
# *****************
# index:  18 keywords:  martian atmosphere
# Word DOES NOT exists in WordNet
# *****************
# index:  19 keywords:  synthetic biology
# Word DOES NOT exists in WordNet
# *****************
# index:  20 keywords:  expose r2 mission
# Word DOES NOT exists in WordNet
# *****************
# index:  21 keywords:  mars
# Word exists in WordNet
# *****************
# j:  13
# initial key:  T13
# j:  14
# key:  T14
# j:  15
# key:  T15
# index:  22 keywords:  desiccation
# Word exists in WordNet
# *****************
# j:  15
# initial key:  T15
# j:  16
# key:  T16
# j:  17
# key:  T17
# j:  18
# key:  T18
# index:  23 keywords:  habitability
# Word exists in WordNet
# *****************
# j:  18
# initial key:  T18
# j:  19
# key:  T19
# j:  20
# key:  T20
# j:  21
# key:  T21
# index:  24 keywords:  perchlorate
# Word exists in WordNet
# *****************
# j:  21
# initial key:  T21
# j:  22
# key:  T22
# j:  23
# key:  T23
# j:  24
# key:  T24
# index:  25 keywords:  stability
# Word exists in WordNet
# *****************
# j:  24
# initial key:  T24
# j:  25
# key:  T25
# j:  26
# key:  T26
# j:  27
# key:  T27
# index:  26 keywords:  astrobiology
# Word exists in WordNet
# *****************
# j:  27
# initial key:  T27
# j:  28
# key:  T28
# j:  29
# key:  T29
# j:  30
# key:  T30
# index:  27 keywords:  astrochemistry
# Word DOES NOT exists in WordNet
# *****************
# index:  28 keywords:  comets
# Word DOES NOT exists in WordNet
# *****************
# index:  29 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  30 keywords:  photochemistry
# Word exists in WordNet
# *****************
# j:  30
# initial key:  T30
# j:  31
# key:  T31
# j:  32
# key:  T32
# j:  33
# key:  T33
# index:  31 keywords:  infrared spectroscopy
# Word DOES NOT exists in WordNet
# *****************
# index:  32 keywords:  ultracarbonaceous antarctic micrometeorites
# Word DOES NOT exists in WordNet
# *****************
# index:  33 keywords:  ion irradiation
# Word DOES NOT exists in WordNet
# *****************
# index:  34 keywords:  oort cloud
# Word exists in WordNet
# *****************
# j:  33
# initial key:  T33
# j:  34
# key:  T34
# j:  35
# key:  T35
# j:  36
# key:  T36
# index:  35 keywords:  absorption
# Word exists in WordNet
# *****************
# j:  36
# initial key:  T36
# j:  37
# key:  T37
# j:  38
# key:  T38
# j:  39
# key:  T39
# index:  36 keywords:  nitrogen
# Word exists in WordNet
# *****************
# j:  39
# initial key:  T39
# j:  40
# key:  T40
# j:  41
# key:  T41
# j:  42
# key:  T42
# index:  37 keywords:  particles
# Word DOES NOT exists in WordNet
# *****************
# index:  38 keywords:  chemistry
# Word exists in WordNet
# *****************
# j:  42
# initial key:  T42
# j:  43
# key:  T43
# j:  44
# key:  T44
# j:  45
# key:  T45
# index:  39 keywords:  carbon
# Word exists in WordNet
# *****************
# j:  45
# initial key:  T45
# j:  46
# key:  T46
# j:  47
# key:  T47
# j:  48
# key:  T48
# index:  40 keywords:  identification
# Word exists in WordNet
# *****************
# j:  48
# initial key:  T48
# j:  49
# key:  T49
# j:  50
# key:  T50
# j:  51
# key:  T51
# index:  41 keywords:  spectroscopy
# Word exists in WordNet
# *****************
# j:  51
# initial key:  T51
# j:  52
# key:  T52
# j:  53
# key:  T53
# j:  54
# key:  T54
# index:  42 keywords:  diffusion
# Word exists in WordNet
# *****************
# j:  54
# initial key:  T54
# j:  55
# key:  T55
# j:  56
# key:  T56
# j:  57
# key:  T57
# index:  43 keywords:  dusty plasma
# Word DOES NOT exists in WordNet
# *****************
# index:  44 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  45 keywords:  plasmakristall 4 (pk 4)
# Word DOES NOT exists in WordNet
# *****************
# index:  46 keywords:  anomalous diffusion
# Word DOES NOT exists in WordNet
# *****************
# index:  47 keywords:  dust particles
# Word DOES NOT exists in WordNet
# *****************
# index:  48 keywords:  dynamics
# Word exists in WordNet
# *****************
# j:  57
# initial key:  T57
# j:  58
# key:  T58
# j:  59
# key:  T59
# j:  60
# key:  T60
# index:  49 keywords:  forces
# Word DOES NOT exists in WordNet
# *****************
# index:  50 keywords:  plasma
# Word exists in WordNet
# *****************
# j:  60
# initial key:  T60
# j:  61
# key:  T61
# j:  62
# key:  T62
# j:  63
# key:  T63
# index:  51 keywords:  aerospace medicine
# Word exists in WordNet
# *****************
# j:  63
# initial key:  T63
# j:  64
# key:  T64
# j:  65
# key:  T65
# j:  66
# key:  T66
# index:  52 keywords:  atrophy
# Word exists in WordNet
# *****************
# j:  66
# initial key:  T66
# j:  67
# key:  T67
# j:  68
# key:  T68
# j:  69
# key:  T69
# index:  53 keywords:  back pain
# Word DOES NOT exists in WordNet
# *****************
# index:  54 keywords:  computed tomography imaging
# Word DOES NOT exists in WordNet
# *****************
# index:  55 keywords:  in flight exercise
# Word DOES NOT exists in WordNet
# *****************
# index:  56 keywords:  intramuscular fatty infiltration
# Word DOES NOT exists in WordNet
# *****************
# index:  57 keywords:  muscle attenuation
# Word DOES NOT exists in WordNet
# *****************
# index:  58 keywords:  muscles
# Word DOES NOT exists in WordNet
# *****************
# index:  59 keywords:  paraspinal muscles
# Word DOES NOT exists in WordNet
# *****************
# index:  60 keywords:  weightlessness
# Word exists in WordNet
# *****************
# j:  69
# initial key:  T69
# j:  70
# key:  T70
# j:  71
# key:  T71
# j:  72
# key:  T72
# index:  61 keywords:  low back pain
# Word DOES NOT exists in WordNet
# *****************
# index:  62 keywords:  fat infiltration
# Word DOES NOT exists in WordNet
# *****************
# index:  63 keywords:  mechanical properties
# Word DOES NOT exists in WordNet
# *****************
# index:  64 keywords:  bed rest
# Word exists in WordNet
# *****************
# j:  72
# initial key:  T72
# j:  73
# key:  T73
# j:  74
# key:  T74
# j:  75
# key:  T75
# index:  65 keywords:  space
# Word exists in WordNet
# *****************
# j:  75
# initial key:  T75
# j:  76
# key:  T76
# j:  77
# key:  T77
# j:  78
# key:  T78
# index:  66 keywords:  spine
# Word exists in WordNet
# *****************
# j:  78
# initial key:  T78
# j:  79
# key:  T79
# j:  80
# key:  T80
# j:  81
# key:  T81
# index:  67 keywords:  attenuation
# Word exists in WordNet
# *****************
# j:  81
# initial key:  T81
# j:  82
# key:  T82
# j:  83
# key:  T83
# j:  84
# key:  T84
# index:  68 keywords:  astronauts
# Word DOES NOT exists in WordNet
# *****************
# index:  69 keywords:  hip
# Word exists in WordNet
# *****************
# j:  84
# initial key:  T84
# j:  85
# key:  T85
# j:  86
# key:  T86
# j:  87
# key:  T87
# index:  70 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  71 keywords:  alloys
# Word DOES NOT exists in WordNet
# *****************
# index:  72 keywords:  directional solidification
# Word DOES NOT exists in WordNet
# *****************
# index:  73 keywords:  microgravity conditions
# Word DOES NOT exists in WordNet
# *****************
# index:  74 keywords:  convection
# Word exists in WordNet
# *****************
# j:  87
# initial key:  T87
# j:  88
# key:  T88
# j:  89
# key:  T89
# j:  90
# key:  T90
# index:  75 keywords:  columnar to equiaxed transition
# Word DOES NOT exists in WordNet
# *****************
# index:  76 keywords:  solute diffusion model
# Word DOES NOT exists in WordNet
# *****************
# index:  77 keywords:  natural convection
# Word DOES NOT exists in WordNet
# *****************
# index:  78 keywords:  grain refinement
# Word DOES NOT exists in WordNet
# *****************
# index:  79 keywords:  unconstrained growth
# Word DOES NOT exists in WordNet
# *****************
# index:  80 keywords:  melt convection
# Word DOES NOT exists in WordNet
# *****************
# index:  81 keywords:  metallic alloys
# Word DOES NOT exists in WordNet
# *****************
# index:  82 keywords:  fluid flow
# Word DOES NOT exists in WordNet
# *****************
# index:  83 keywords:  macrosegregation
# Word DOES NOT exists in WordNet
# *****************
# index:  84 keywords:  microstructure
# Word DOES NOT exists in WordNet
# *****************
# index:  85 keywords:  aluminum
# Word exists in WordNet
# *****************
# j:  90
# initial key:  T90
# j:  91
# key:  T91
# j:  92
# key:  T92
# j:  93
# key:  T93
# index:  86 keywords:  astronauts
# Word DOES NOT exists in WordNet
# *****************
# index:  87 keywords:  immunity
# Word exists in WordNet
# *****************
# j:  93
# initial key:  T93
# j:  94
# key:  T94
# j:  95
# key:  T95
# j:  96
# key:  T96
# index:  88 keywords:  isolation and confinement
# Word DOES NOT exists in WordNet
# *****************
# index:  89 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  90 keywords:  space exploration
# Word DOES NOT exists in WordNet
# *****************
# index:  91 keywords:  immune system dysregulation
# Word DOES NOT exists in WordNet
# *****************
# index:  92 keywords:  latent cytomegalovirus infection
# Word DOES NOT exists in WordNet
# *****************
# index:  93 keywords:  highly differentiated phenotype
# Word DOES NOT exists in WordNet
# *****************
# index:  94 keywords:  epstein barr virus
# Word DOES NOT exists in WordNet
# *****************
# index:  95 keywords:  augments cytotoxicity
# Word DOES NOT exists in WordNet
# *****************
# index:  96 keywords:  natural cytotoxicity
# Word DOES NOT exists in WordNet
# *****************
# index:  97 keywords:  reactivation
# Word DOES NOT exists in WordNet
# *****************
# index:  98 keywords:  expression
# Word exists in WordNet
# *****************
# j:  96
# initial key:  T96
# j:  97
# key:  T97
# j:  98
# key:  T98
# j:  99
# key:  T99
# index:  99 keywords:  risk
# Word exists in WordNet
# *****************
# j:  99
# initial key:  T99
# j:  100
# key:  T100
# j:  101
# key:  T101
# j:  102
# key:  T102
# index:  100 keywords:  exploration
# Word exists in WordNet
# *****************
# j:  102
# initial key:  T102
# j:  103
# key:  T103
# j:  104
# key:  T104
# j:  105
# key:  T105
# index:  101 keywords:  lengths and angles of fibers
# Word DOES NOT exists in WordNet
# *****************
# index:  102 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  105
# initial key:  T105
# j:  106
# key:  T106
# j:  107
# key:  T107
# j:  108
# key:  T108
# index:  103 keywords:  ultrasonography
# Word exists in WordNet
# *****************
# j:  108
# initial key:  T108
# j:  109
# key:  T109
# j:  110
# key:  T110
# j:  111
# key:  T111
# index:  104 keywords:  voluntary and evoked contractions
# Word DOES NOT exists in WordNet
# *****************
# index:  105 keywords:  human skeletal muscle
# Word DOES NOT exists in WordNet
# *****************
# index:  106 keywords:  cross sectional area
# Word DOES NOT exists in WordNet
# *****************
# index:  107 keywords:  bed rest
# Word exists in WordNet
# *****************
# j:  111
# initial key:  T111
# j:  112
# key:  T112
# j:  113
# key:  T113
# j:  114
# key:  T114
# index:  108 keywords:  sarcoplasmic reticulum
# Word DOES NOT exists in WordNet
# *****************
# index:  109 keywords:  simulated microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  110 keywords:  contractile properties
# Word DOES NOT exists in WordNet
# *****************
# index:  111 keywords:  mechanical properties
# Word DOES NOT exists in WordNet
# *****************
# index:  112 keywords:  medial gastrocnemius
# Word DOES NOT exists in WordNet
# *****************
# index:  113 keywords:  electromechanical delay
# Word DOES NOT exists in WordNet
# *****************
# index:  114 keywords:  clinical significance
# Word DOES NOT exists in WordNet
# *****************
# index:  115 keywords:  free water elimination
# Word DOES NOT exists in WordNet
# *****************
# index:  116 keywords:  wallerian degeneration
# Word DOES NOT exists in WordNet
# *****************
# index:  117 keywords:  supramarginal gyrus
# Word DOES NOT exists in WordNet
# *****************
# index:  118 keywords:  diffusion
# Word exists in WordNet
# *****************
# j:  114
# initial key:  T114
# j:  115
# key:  T115
# j:  116
# key:  T116
# j:  117
# key:  T117
# index:  119 keywords:  performance
# Word exists in WordNet
# *****************
# j:  117
# initial key:  T117
# j:  118
# key:  T118
# j:  119
# key:  T119
# j:  120
# key:  T120
# index:  120 keywords:  dependence
# Word exists in WordNet
# *****************
# j:  120
# initial key:  T120
# j:  121
# key:  T121
# j:  122
# key:  T122
# j:  123
# key:  T123
# index:  121 keywords:  pathways
# Word DOES NOT exists in WordNet
# *****************
# index:  122 keywords:  healthy
# Word exists in WordNet
# *****************
# j:  123
# initial key:  T123
# j:  124
# key:  T124
# j:  125
# key:  T125
# index:  123 keywords:  dti
# Word DOES NOT exists in WordNet
# *****************
# index:  124 keywords:  microrna 206
# Word DOES NOT exists in WordNet
# *****************
# index:  125 keywords:  inflamma mirs
# Word DOES NOT exists in WordNet
# *****************
# index:  126 keywords:  proteasome
# Word DOES NOT exists in WordNet
# *****************
# index:  127 keywords:  serpina1
# Word DOES NOT exists in WordNet
# *****************
# index:  128 keywords:  circulating micrornas
# Word DOES NOT exists in WordNet
# *****************
# index:  129 keywords:  skeletal muscle
# Word exists in WordNet
# *****************
# j:  125
# initial key:  T125
# j:  126
# key:  T126
# j:  127
# key:  T127
# j:  128
# key:  T128
# index:  130 keywords:  inflammation
# Word exists in WordNet
# *****************
# j:  128
# initial key:  T128
# j:  129
# key:  T129
# j:  130
# key:  T130
# j:  131
# key:  T131
# index:  131 keywords:  senescence
# Word exists in WordNet
# *****************
# j:  131
# initial key:  T131
# j:  132
# key:  T132
# j:  133
# key:  T133
# j:  134
# key:  T134
# index:  132 keywords:  expression
# Word exists in WordNet
# *****************
# j:  134
# initial key:  T134
# j:  135
# key:  T135
# j:  136
# key:  T136
# j:  137
# key:  T137
# index:  133 keywords:  longevity
# Word exists in WordNet
# *****************
# j:  137
# initial key:  T137
# j:  138
# key:  T138
# j:  139
# key:  T139
# j:  140
# key:  T140
# index:  134 keywords:  relevance
# Word exists in WordNet
# *****************
# j:  140
# initial key:  T140
# j:  141
# key:  T141
# j:  142
# key:  T142
# j:  143
# key:  T143
# index:  135 keywords:  exercise
# Word exists in WordNet
# *****************
# j:  143
# initial key:  T143
# j:  144
# key:  T144
# j:  145
# key:  T145
# j:  146
# key:  T146
# index:  136 keywords:  tissues
# Word DOES NOT exists in WordNet
# *****************
# index:  137 keywords:  mir 21
# Word DOES NOT exists in WordNet
# *****************
# index:  138 keywords:  thermocapillary convection
# Word DOES NOT exists in WordNet
# *****************
# index:  139 keywords:  liquid bridge
# Word DOES NOT exists in WordNet
# *****************
# index:  140 keywords:  radiative heat transfer
# Word DOES NOT exists in WordNet
# *****************
# index:  141 keywords:  convective heat transfer
# Word DOES NOT exists in WordNet
# *****************
# index:  142 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  143 keywords:  marangoni convection
# Word DOES NOT exists in WordNet
# *****************
# index:  144 keywords:  floating zone
# Word DOES NOT exists in WordNet
# *****************
# index:  145 keywords:  gas flow
# Word DOES NOT exists in WordNet
# *****************
# index:  146 keywords:  instability
# Word exists in WordNet
# *****************
# j:  146
# initial key:  T146
# j:  147
# key:  T147
# j:  148
# key:  T148
# j:  149
# key:  T149
# index:  147 keywords:  stability
# Word exists in WordNet
# *****************
# j:  149
# initial key:  T149
# j:  150
# key:  T150
# j:  151
# key:  T151
# j:  152
# key:  T152
# index:  148 keywords:  temperature
# Word exists in WordNet
# *****************
# j:  152
# initial key:  T152
# j:  153
# key:  T153
# j:  154
# key:  T154
# j:  155
# key:  T155
# index:  149 keywords:  antimicrobial surface
# Word DOES NOT exists in WordNet
# *****************
# index:  150 keywords:  gram positive human pathogenic bacteria
# Word DOES NOT exists in WordNet
# *****************
# index:  151 keywords:  antibiotic resistance
# Word DOES NOT exists in WordNet
# *****************
# index:  152 keywords:  biofilm
# Word DOES NOT exists in WordNet
# *****************
# index:  153 keywords:  conjugative transfer
# Word DOES NOT exists in WordNet
# *****************
# index:  154 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  155 keywords:  hostile environment
# Word DOES NOT exists in WordNet
# *****************
# index:  156 keywords:  complete nucleotide sequence
# Word DOES NOT exists in WordNet
# *****************
# index:  157 keywords:  mobile genetic elements
# Word DOES NOT exists in WordNet
# *****************
# index:  158 keywords:  staphylococcus aureus
# Word DOES NOT exists in WordNet
# *****************
# index:  159 keywords:  microbial contamination
# Word DOES NOT exists in WordNet
# *****************
# index:  160 keywords:  escherichia coli
# Word exists in WordNet
# *****************
# j:  155
# initial key:  T155
# j:  156
# key:  T156
# j:  157
# key:  T157
# j:  158
# key:  T158
# index:  161 keywords:  immune system
# Word exists in WordNet
# *****************
# j:  158
# initial key:  T158
# j:  159
# key:  T159
# j:  160
# key:  T160
# j:  161
# key:  T161
# index:  162 keywords:  high level
# Word DOES NOT exists in WordNet
# *****************
# index:  163 keywords:  tetracycline
# Word exists in WordNet
# *****************
# j:  161
# initial key:  T161
# j:  162
# key:  T162
# j:  163
# key:  T163
# j:  164
# key:  T164
# index:  164 keywords:  plasmid
# Word exists in WordNet
# *****************
# j:  164
# initial key:  T164
# j:  165
# key:  T165
# j:  166
# key:  T166
# j:  167
# key:  T167
# index:  165 keywords:  flight
# Word exists in WordNet
# *****************
# j:  167
# initial key:  T167
# j:  168
# key:  T168
# j:  169
# key:  T169
# j:  170
# key:  T170
# index:  166 keywords:  cortisol
# Word exists in WordNet
# *****************
# j:  170
# initial key:  T170
# j:  171
# key:  T171
# j:  172
# key:  T172
# j:  173
# key:  T173
# index:  167 keywords:  chemiluminescence biosensor
# Word DOES NOT exists in WordNet
# *****************
# index:  168 keywords:  lateral flow immunoassay
# Word DOES NOT exists in WordNet
# *****************
# index:  169 keywords:  space medicine
# Word exists in WordNet
# *****************
# j:  173
# initial key:  T173
# j:  174
# key:  T174
# j:  175
# key:  T175
# j:  176
# key:  T176
# index:  170 keywords:  point of care testing
# Word DOES NOT exists in WordNet
# *****************
# index:  171 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  172 keywords:  fumonisins
# Word DOES NOT exists in WordNet
# *****************
# index:  173 keywords:  biomarker
# Word DOES NOT exists in WordNet
# *****************
# index:  174 keywords:  devices
# Word exists in WordNet
# *****************
# j:  176
# initial key:  T176
# j:  177
# key:  T177
# j:  178
# key:  T178
# j:  179
# key:  T179
# index:  175 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  179
# initial key:  T179
# j:  180
# key:  T180
# j:  181
# key:  T181
# j:  182
# key:  T182
# index:  176 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  177 keywords:  arabidopsis
# Word exists in WordNet
# *****************
# j:  182
# initial key:  T182
# j:  183
# key:  T183
# j:  184
# key:  T184
# j:  185
# key:  T185
# index:  178 keywords:  transcriptome
# Word DOES NOT exists in WordNet
# *****************
# index:  179 keywords:  dna methylation
# Word DOES NOT exists in WordNet
# *****************
# index:  180 keywords:  epigenome
# Word DOES NOT exists in WordNet
# *****************
# index:  181 keywords:  epigenetic
# Word DOES NOT exists in WordNet
# *****************
# index:  182 keywords:  veggie
# Word exists in WordNet
# *****************
# j:  185
# initial key:  T185
# j:  186
# key:  T186
# j:  187
# key:  T187
# j:  188
# key:  T188
# index:  183 keywords:  iss
# Word DOES NOT exists in WordNet
# *****************
# index:  184 keywords:  genome wide analysis
# Word DOES NOT exists in WordNet
# *****************
# index:  185 keywords:  ksc fixation tubes
# Word DOES NOT exists in WordNet
# *****************
# index:  186 keywords:  epigenetic regulation
# Word DOES NOT exists in WordNet
# *****************
# index:  187 keywords:  stress response
# Word DOES NOT exists in WordNet
# *****************
# index:  188 keywords:  abiotic stress
# Word DOES NOT exists in WordNet
# *****************
# index:  189 keywords:  plant development
# Word DOES NOT exists in WordNet
# *****************
# index:  190 keywords:  space flight
# Word DOES NOT exists in WordNet
# *****************
# index:  191 keywords:  seedlings
# Word DOES NOT exists in WordNet
# *****************
# index:  192 keywords:  patterns
# Word DOES NOT exists in WordNet
# *****************
# index:  193 keywords:  magnetic fields
# Word DOES NOT exists in WordNet
# *****************
# index:  194 keywords:  stars: magnetars
# Word DOES NOT exists in WordNet
# *****************
# index:  195 keywords:  stars: neutron
# Word DOES NOT exists in WordNet
# *****************
# index:  196 keywords:  pulsars: individual: xte j1810 197
# Word DOES NOT exists in WordNet
# *****************
# index:  197 keywords:  x rays: stars
# Word DOES NOT exists in WordNet
# *****************
# index:  198 keywords:  x ray emission
# Word DOES NOT exists in WordNet
# *****************
# index:  199 keywords:  transient magnetar
# Word DOES NOT exists in WordNet
# *****************
# index:  200 keywords:  radio emission
# Word exists in WordNet
# *****************
# j:  188
# initial key:  T188
# j:  189
# key:  T189
# j:  190
# key:  T190
# j:  191
# key:  T191
# index:  201 keywords:  1e 1547.0 5408
# Word DOES NOT exists in WordNet
# *****************
# index:  202 keywords:  neutron stars
# Word DOES NOT exists in WordNet
# *****************
# index:  203 keywords:  spin down
# Word DOES NOT exists in WordNet
# *****************
# index:  204 keywords:  absorption
# Word exists in WordNet
# *****************
# j:  191
# initial key:  T191
# j:  192
# key:  T192
# j:  193
# key:  T193
# j:  194
# key:  T194
# index:  205 keywords:  discovery
# Word exists in WordNet
# *****************
# j:  194
# initial key:  T194
# j:  195
# key:  T195
# j:  196
# key:  T196
# j:  197
# key:  T197
# index:  206 keywords:  bursts
# Word DOES NOT exists in WordNet
# *****************
# index:  207 keywords:  aspergillus fumigatus
# Word exists in WordNet
# *****************
# j:  197
# initial key:  T197
# j:  198
# key:  T198
# j:  199
# key:  T199
# j:  200
# key:  T200
# index:  208 keywords:  proteome
# Word exists in WordNet
# *****************
# j:  200
# initial key:  T200
# j:  201
# key:  T201
# j:  202
# key:  T202
# j:  203
# key:  T203
# index:  209 keywords:  the international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  210 keywords:  asp hemolysin
# Word DOES NOT exists in WordNet
# *****************
# index:  211 keywords:  gene cluster
# Word DOES NOT exists in WordNet
# *****************
# index:  212 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  203
# initial key:  T203
# j:  204
# key:  T204
# j:  205
# key:  T205
# j:  206
# key:  T206
# index:  213 keywords:  proteins
# Word DOES NOT exists in WordNet
# *****************
# index:  214 keywords:  stress
# Word exists in WordNet
# *****************
# j:  206
# initial key:  T206
# j:  207
# key:  T207
# j:  208
# key:  T208
# j:  209
# key:  T209
# index:  215 keywords:  board
# Word exists in WordNet
# *****************
# j:  209
# initial key:  T209
# j:  210
# key:  T210
# j:  211
# key:  T211
# j:  212
# key:  T212
# index:  216 keywords:  identification
# Word exists in WordNet
# *****************
# j:  212
# initial key:  T212
# j:  213
# key:  T213
# j:  214
# key:  T214
# j:  215
# key:  T215
# index:  217 keywords:  adaptation
# Word exists in WordNet
# *****************
# j:  215
# initial key:  T215
# j:  216
# key:  T216
# j:  217
# key:  T217
# j:  218
# key:  T218
# index:  218 keywords:  database
# Word exists in WordNet
# *****************
# j:  218
# initial key:  T218
# j:  219
# key:  T219
# j:  220
# key:  T220
# j:  221
# key:  T221
# index:  219 keywords:  fungi
# Word exists in WordNet
# *****************
# j:  221
# initial key:  T221
# j:  222
# key:  T222
# j:  223
# key:  T223
# j:  224
# key:  T224
# index:  220 keywords:  manufacturing in space
# Word DOES NOT exists in WordNet
# *****************
# index:  221 keywords:  3d printing
# Word DOES NOT exists in WordNet
# *****************
# index:  222 keywords:  additive manufacturing
# Word DOES NOT exists in WordNet
# *****************
# index:  223 keywords:  rapid prototyping
# Word DOES NOT exists in WordNet
# *****************
# index:  224 keywords:  abs
# Word exists in WordNet
# *****************
# j:  224
# initial key:  T224
# j:  225
# key:  T225
# j:  226
# key:  T226
# j:  227
# key:  T227
# index:  225 keywords:  behavior
# Word exists in WordNet
# *****************
# j:  227
# initial key:  T227
# j:  228
# key:  T228
# j:  229
# key:  T229
# j:  230
# key:  T230
# index:  226 keywords:  active galactic nuclei
# Word DOES NOT exists in WordNet
# *****************
# index:  227 keywords:  tidal disruption event
# Word DOES NOT exists in WordNet
# *****************
# index:  228 keywords:  narrow line region
# Word DOES NOT exists in WordNet
# *****************
# index:  229 keywords:  bowen fluorescence
# Word DOES NOT exists in WordNet
# *****************
# index:  230 keywords:  star formation
# Word DOES NOT exists in WordNet
# *****************
# index:  231 keywords:  luminosity
# Word exists in WordNet
# *****************
# j:  230
# initial key:  T230
# j:  231
# key:  T231
# j:  232
# key:  T232
# j:  233
# key:  T233
# index:  232 keywords:  galaxies
# Word DOES NOT exists in WordNet
# *****************
# index:  233 keywords:  mass
# Word exists in WordNet
# *****************
# j:  233
# initial key:  T233
# j:  234
# key:  T234
# j:  235
# key:  T235
# j:  236
# key:  T236
# index:  234 keywords:  emission
# Word exists in WordNet
# *****************
# j:  236
# initial key:  T236
# j:  237
# key:  T237
# j:  238
# key:  T238
# j:  239
# key:  T239
# index:  235 keywords:  quasars
# Word DOES NOT exists in WordNet
# *****************
# index:  236 keywords:  free moving part
# Word DOES NOT exists in WordNet
# *****************
# index:  237 keywords:  phaseolus vulgaris
# Word exists in WordNet
# *****************
# j:  239
# initial key:  T239
# j:  240
# key:  T240
# j:  241
# key:  T241
# j:  242
# key:  T242
# index:  238 keywords:  arabidopsis
# Word exists in WordNet
# *****************
# j:  242
# initial key:  T242
# j:  243
# key:  T243
# j:  244
# key:  T244
# j:  245
# key:  T245
# index:  239 keywords:  elongation
# Word exists in WordNet
# *****************
# j:  245
# initial key:  T245
# j:  246
# key:  T246
# j:  247
# key:  T247
# j:  248
# key:  T248
# index:  240 keywords:  lazy1
# Word DOES NOT exists in WordNet
# *****************
# index:  241 keywords:  hypocotyls
# Word DOES NOT exists in WordNet
# *****************
# index:  242 keywords:  shoots
# Word DOES NOT exists in WordNet
# *****************
# index:  243 keywords:  force
# Word exists in WordNet
# *****************
# j:  248
# initial key:  T248
# j:  249
# key:  T249
# j:  250
# key:  T250
# j:  251
# key:  T251
# index:  244 keywords:  plays
# Word DOES NOT exists in WordNet
# *****************
# index:  245 keywords:  galvanic vestibular stimulation
# Word DOES NOT exists in WordNet
# *****************
# index:  246 keywords:  space
# Word exists in WordNet
# *****************
# j:  251
# initial key:  T251
# j:  252
# key:  T252
# j:  253
# key:  T253
# j:  254
# key:  T254
# index:  247 keywords:  performance
# Word exists in WordNet
# *****************
# j:  254
# initial key:  T254
# j:  255
# key:  T255
# j:  256
# key:  T256
# j:  257
# key:  T257
# index:  248 keywords:  coordination
# Word exists in WordNet
# *****************
# j:  257
# initial key:  T257
# j:  258
# key:  T258
# j:  259
# key:  T259
# j:  260
# key:  T260
# index:  249 keywords:  adaptation
# Word exists in WordNet
# *****************
# j:  260
# initial key:  T260
# j:  261
# key:  T261
# j:  262
# key:  T262
# j:  263
# key:  T263
# index:  250 keywords:  perception
# Word exists in WordNet
# *****************
# j:  263
# initial key:  T263
# j:  264
# key:  T264
# j:  265
# key:  T265
# j:  266
# key:  T266
# index:  251 keywords:  analog
# Word exists in WordNet
# *****************
# j:  266
# initial key:  T266
# j:  267
# key:  T267
# j:  268
# key:  T268
# j:  269
# key:  T269
# index:  252 keywords:  tilt
# Word exists in WordNet
# *****************
# j:  269
# initial key:  T269
# j:  270
# key:  T270
# j:  271
# key:  T271
# j:  272
# key:  T272
# index:  253 keywords:  gravitation
# Word exists in WordNet
# *****************
# j:  272
# initial key:  T272
# j:  273
# key:  T273
# j:  274
# key:  T274
# j:  275
# key:  T275
# index:  254 keywords:  plasmas
# Word DOES NOT exists in WordNet
# *****************
# index:  255 keywords:  pulsars: general
# Word DOES NOT exists in WordNet
# *****************
# index:  256 keywords:  relativistic processes
# Word DOES NOT exists in WordNet
# *****************
# index:  257 keywords:  stars: neutron
# Word DOES NOT exists in WordNet
# *****************
# index:  258 keywords:  x rays: stars
# Word DOES NOT exists in WordNet
# *****************
# index:  259 keywords:  pulsar light curves
# Word DOES NOT exists in WordNet
# *****************
# index:  260 keywords:  x ray emission
# Word DOES NOT exists in WordNet
# *****************
# index:  261 keywords:  model atmospheres
# Word DOES NOT exists in WordNet
# *****************
# index:  262 keywords:  millisecond pulsars
# Word DOES NOT exists in WordNet
# *****************
# index:  263 keywords:  pair creation
# Word exists in WordNet
# *****************
# j:  275
# initial key:  T275
# j:  276
# key:  T276
# j:  277
# key:  T277
# j:  278
# key:  T278
# index:  264 keywords:  hot spots
# Word DOES NOT exists in WordNet
# *****************
# index:  265 keywords:  spectra
# Word DOES NOT exists in WordNet
# *****************
# index:  266 keywords:  polarization
# Word exists in WordNet
# *****************
# j:  278
# initial key:  T278
# j:  279
# key:  T279
# j:  280
# key:  T280
# j:  281
# key:  T281
# index:  267 keywords:  simulations
# Word DOES NOT exists in WordNet
# *****************
# index:  268 keywords:  space radiation
# Word DOES NOT exists in WordNet
# *****************
# index:  269 keywords:  genelab
# Word DOES NOT exists in WordNet
# *****************
# index:  270 keywords:  cardiovascular
# Word exists in WordNet
# *****************
# j:  281
# initial key:  T281
# j:  282
# key:  T282
# j:  283
# key:  T283
# index:  271 keywords:  huvecs
# Word DOES NOT exists in WordNet
# *****************
# index:  272 keywords:  fyn
# Word DOES NOT exists in WordNet
# *****************
# index:  273 keywords:  ros
# Word DOES NOT exists in WordNet
# *****************
# index:  274 keywords:  reactive oxygen species
# Word DOES NOT exists in WordNet
# *****************
# index:  275 keywords:  cardiomyocytes
# Word DOES NOT exists in WordNet
# *****************
# index:  276 keywords:  protons
# Word DOES NOT exists in WordNet
# *****************
# index:  277 keywords:  iron
# Word exists in WordNet
# *****************
# j:  283
# initial key:  T283
# j:  284
# key:  T284
# j:  285
# key:  T285
# j:  286
# key:  T286
# index:  278 keywords:  hze irradiation
# Word DOES NOT exists in WordNet
# *****************
# index:  279 keywords:  src family kinases
# Word DOES NOT exists in WordNet
# *****************
# index:  280 keywords:  ionizing radiation
# Word exists in WordNet
# *****************
# j:  286
# initial key:  T286
# j:  287
# key:  T287
# j:  288
# key:  T288
# j:  289
# key:  T289
# index:  281 keywords:  oxidative stress
# Word DOES NOT exists in WordNet
# *****************
# index:  282 keywords:  t cell
# Word exists in WordNet
# *****************
# j:  289
# initial key:  T289
# j:  290
# key:  T290
# j:  291
# key:  T291
# j:  292
# key:  T292
# index:  283 keywords:  dna methylation
# Word DOES NOT exists in WordNet
# *****************
# index:  284 keywords:  bomb survivors
# Word DOES NOT exists in WordNet
# *****************
# index:  285 keywords:  disease
# Word exists in WordNet
# *****************
# j:  292
# initial key:  T292
# j:  293
# key:  T293
# j:  294
# key:  T294
# j:  295
# key:  T295
# index:  286 keywords:  age
# Word exists in WordNet
# *****************
# j:  295
# initial key:  T295
# j:  296
# key:  T296
# j:  297
# key:  T297
# j:  298
# key:  T298
# index:  287 keywords:  progression
# Word exists in WordNet
# *****************
# j:  298
# initial key:  T298
# j:  299
# key:  T299
# j:  300
# key:  T300
# j:  301
# key:  T301
# index:  288 keywords:  expression
# Word exists in WordNet
# *****************
# j:  301
# initial key:  T301
# j:  302
# key:  T302
# j:  303
# key:  T303
# j:  304
# key:  T304
# index:  289 keywords:  soret
# Word DOES NOT exists in WordNet
# *****************
# index:  290 keywords:  convection
# Word exists in WordNet
# *****************
# j:  304
# initial key:  T304
# j:  305
# key:  T305
# j:  306
# key:  T306
# j:  307
# key:  T307
# index:  291 keywords:  dcmix
# Word DOES NOT exists in WordNet
# *****************
# index:  292 keywords:  temperature perturbation
# Word DOES NOT exists in WordNet
# *****************
# index:  293 keywords:  ternary mixtures measurement
# Word DOES NOT exists in WordNet
# *****************
# index:  294 keywords:  binary mixture
# Word DOES NOT exists in WordNet
# *****************
# index:  295 keywords:  diffusion coefficients
# Word DOES NOT exists in WordNet
# *****************
# index:  296 keywords:  nonlinear regimes
# Word DOES NOT exists in WordNet
# *****************
# index:  297 keywords:  horizontal layer
# Word DOES NOT exists in WordNet
# *****************
# index:  298 keywords:  thermodiffusion
# Word DOES NOT exists in WordNet
# *****************
# index:  299 keywords:  benchmark
# Word exists in WordNet
# *****************
# j:  307
# initial key:  T307
# j:  308
# key:  T308
# j:  309
# key:  T309
# j:  310
# key:  T310
# index:  300 keywords:  onset
# Word exists in WordNet
# *****************
# j:  310
# initial key:  T310
# j:  311
# key:  T311
# j:  312
# key:  T312
# j:  313
# key:  T313
# index:  301 keywords:  isobutylbenzene
# Word DOES NOT exists in WordNet
# *****************
# index:  302 keywords:  soret effect
# Word DOES NOT exists in WordNet
# *****************
# index:  303 keywords:  microgravity experiment
# Word DOES NOT exists in WordNet
# *****************
# index:  304 keywords:  salol
# Word exists in WordNet
# *****************
# j:  313
# initial key:  T313
# j:  314
# key:  T314
# j:  315
# key:  T315
# j:  316
# key:  T316
# index:  305 keywords:  tert butyl alcohol
# Word DOES NOT exists in WordNet
# *****************
# index:  306 keywords:  two wavelength mach zehnder interferometer
# Word DOES NOT exists in WordNet
# *****************
# index:  307 keywords:  cellular array growth
# Word DOES NOT exists in WordNet
# *****************
# index:  308 keywords:  diffusion coefficients
# Word DOES NOT exists in WordNet
# *****************
# index:  309 keywords:  benchmark values
# Word DOES NOT exists in WordNet
# *****************
# index:  310 keywords:  ternary mixtures
# Word DOES NOT exists in WordNet
# *****************
# index:  311 keywords:  thermodiffusion
# Word DOES NOT exists in WordNet
# *****************
# index:  312 keywords:  b cell homeostasis
# Word DOES NOT exists in WordNet
# *****************
# index:  313 keywords:  free light chains
# Word DOES NOT exists in WordNet
# *****************
# index:  314 keywords:  immunoglobulins
# Word DOES NOT exists in WordNet
# *****************
# index:  315 keywords:  long duration spaceflight
# Word DOES NOT exists in WordNet
# *****************
# index:  316 keywords:  immune system dysregulation
# Word DOES NOT exists in WordNet
# *****************
# index:  317 keywords:  gene expression
# Word exists in WordNet
# *****************
# j:  316
# initial key:  T316
# j:  317
# key:  T317
# j:  318
# key:  T318
# j:  319
# key:  T319
# index:  318 keywords:  latent viruses
# Word DOES NOT exists in WordNet
# *****************
# index:  319 keywords:  space flight
# Word DOES NOT exists in WordNet
# *****************
# index:  320 keywords:  b 1 cells
# Word DOES NOT exists in WordNet
# *****************
# index:  321 keywords:  serum
# Word exists in WordNet
# *****************
# j:  319
# initial key:  T319
# j:  320
# key:  T320
# j:  321
# key:  T321
# j:  322
# key:  T322
# index:  322 keywords:  reactivation
# Word DOES NOT exists in WordNet
# *****************
# index:  323 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  324 keywords:  astronauts
# Word DOES NOT exists in WordNet
# *****************
# index:  325 keywords:  aspergillus nidulans
# Word DOES NOT exists in WordNet
# *****************
# index:  326 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  327 keywords:  genomics
# Word exists in WordNet
# *****************
# j:  322
# initial key:  T322
# j:  323
# key:  T323
# j:  324
# key:  T324
# j:  325
# key:  T325
# index:  328 keywords:  proteomics
# Word exists in WordNet
# *****************
# j:  325
# initial key:  T325
# j:  326
# key:  T326
# j:  327
# key:  T327
# j:  328
# key:  T328
# index:  329 keywords:  metabolomics
# Word DOES NOT exists in WordNet
# *****************
# index:  330 keywords:  filamentous fungi
# Word DOES NOT exists in WordNet
# *****************
# index:  331 keywords:  gene clusters
# Word DOES NOT exists in WordNet
# *****************
# index:  332 keywords:  cell wall
# Word exists in WordNet
# *****************
# j:  328
# initial key:  T328
# j:  329
# key:  T329
# j:  330
# key:  T330
# j:  331
# key:  T331
# index:  333 keywords:  microbial contamination
# Word DOES NOT exists in WordNet
# *****************
# index:  334 keywords:  ionizing radiation
# Word exists in WordNet
# *****************
# j:  331
# initial key:  T331
# j:  332
# key:  T332
# j:  333
# key:  T333
# j:  334
# key:  T334
# index:  335 keywords:  messenger rnas
# Word DOES NOT exists in WordNet
# *****************
# index:  336 keywords:  secondary
# Word exists in WordNet
# *****************
# j:  334
# initial key:  T334
# j:  335
# key:  T335
# j:  336
# key:  T336
# j:  337
# key:  T337
# index:  337 keywords:  degradation
# Word exists in WordNet
# *****************
# j:  337
# initial key:  T337
# j:  338
# key:  T338
# j:  339
# key:  T339
# j:  340
# key:  T340
# index:  338 keywords:  expression
# Word exists in WordNet
# *****************
# j:  340
# initial key:  T340
# j:  341
# key:  T341
# j:  342
# key:  T342
# j:  343
# key:  T343
# index:  339 keywords:  regulator
# Word exists in WordNet
# *****************
# j:  343
# initial key:  T343
# j:  344
# key:  T344
# j:  345
# key:  T345
# j:  346
# key:  T346
# index:  340 keywords:  alpha magnetic spectrometer
# Word DOES NOT exists in WordNet
# *****************
# index:  341 keywords:  geomagnetic reference field
# Word DOES NOT exists in WordNet
# *****************
# index:  342 keywords:  dark matter
# Word exists in WordNet
# *****************
# j:  346
# initial key:  T346
# j:  347
# key:  T347
# j:  348
# key:  T348
# j:  349
# key:  T349
# index:  343 keywords:  energy spectra
# Word DOES NOT exists in WordNet
# *****************
# index:  344 keywords:  ams 02 trd
# Word DOES NOT exists in WordNet
# *****************
# index:  345 keywords:  electrons
# Word DOES NOT exists in WordNet
# *****************
# index:  346 keywords:  space
# Word exists in WordNet
# *****************
# j:  349
# initial key:  T349
# j:  350
# key:  T350
# j:  351
# key:  T351
# j:  352
# key:  T352
# index:  347 keywords:  propagation
# Word exists in WordNet
# *****************
# j:  352
# initial key:  T352
# j:  353
# key:  T353
# j:  354
# key:  T354
# j:  355
# key:  T355
# index:  348 keywords:  performance
# Word exists in WordNet
# *****************
# j:  355
# initial key:  T355
# j:  356
# key:  T356
# j:  357
# key:  T357
# j:  358
# key:  T358
# index:  349 keywords:  detector
# Word exists in WordNet
# *****************
# j:  358
# initial key:  T358
# j:  359
# key:  T359
# j:  360
# key:  T360
# j:  361
# key:  T361
# index:  350 keywords:  x ray reverberation
# Word DOES NOT exists in WordNet
# *****************
# index:  351 keywords:  time lags
# Word DOES NOT exists in WordNet
# *****************
# index:  352 keywords:  iron k
# Word DOES NOT exists in WordNet
# *****************
# index:  353 keywords:  variability
# Word exists in WordNet
# *****************
# j:  361
# initial key:  T361
# j:  362
# key:  T362
# j:  363
# key:  T363
# j:  364
# key:  T364
# index:  354 keywords:  accretion
# Word exists in WordNet
# *****************
# j:  364
# initial key:  T364
# j:  365
# key:  T365
# j:  366
# key:  T366
# j:  367
# key:  T367
# index:  355 keywords:  model
# Word exists in WordNet
# *****************
# j:  367
# initial key:  T367
# j:  368
# key:  T368
# j:  369
# key:  T369
# j:  370
# key:  T370
# index:  356 keywords:  reflection
# Word exists in WordNet
# *****************
# j:  370
# initial key:  T370
# j:  371
# key:  T371
# j:  372
# key:  T372
# j:  373
# key:  T373
# index:  357 keywords:  outbursts
# Word DOES NOT exists in WordNet
# *****************
# index:  358 keywords:  evolution
# Word exists in WordNet
# *****************
# j:  373
# initial key:  T373
# j:  374
# key:  T374
# j:  375
# key:  T375
# j:  376
# key:  T376
# index:  359 keywords:  emission
# Word exists in WordNet
# *****************
# j:  376
# initial key:  T376
# j:  377
# key:  T377
# j:  378
# key:  T378
# j:  379
# key:  T379
# index:  360 keywords:  modeled microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  361 keywords:  gene expression
# Word exists in WordNet
# *****************
# j:  379
# initial key:  T379
# j:  380
# key:  T380
# j:  381
# key:  T381
# j:  382
# key:  T382
# index:  362 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  382
# initial key:  T382
# j:  383
# key:  T383
# j:  384
# key:  T384
# j:  385
# key:  T385
# index:  363 keywords:  biofilm
# Word DOES NOT exists in WordNet
# *****************
# index:  364 keywords:  growth
# Word exists in WordNet
# *****************
# j:  385
# initial key:  T385
# j:  386
# key:  T386
# j:  387
# key:  T387
# j:  388
# key:  T388
# index:  365 keywords:  metabolism
# Word exists in WordNet
# *****************
# j:  388
# initial key:  T388
# j:  389
# key:  T389
# j:  390
# key:  T390
# j:  391
# key:  T391
# index:  366 keywords:  virulence
# Word exists in WordNet
# *****************
# j:  391
# initial key:  T391
# j:  392
# key:  T392
# j:  393
# key:  T393
# j:  394
# key:  T394
# index:  367 keywords:  organism
# Word exists in WordNet
# *****************
# j:  394
# initial key:  T394
# j:  395
# key:  T395
# j:  396
# key:  T396
# j:  397
# key:  T397
# index:  368 keywords:  phase
# Word exists in WordNet
# *****************
# j:  397
# initial key:  T397
# j:  398
# key:  T398
# j:  399
# key:  T399
# j:  400
# key:  T400
# index:  369 keywords:  sporulation
# Word exists in WordNet
# *****************
# j:  400
# initial key:  T400
# j:  401
# key:  T401
# j:  402
# key:  T402
# j:  403
# key:  T403
# index:  370 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  403
# initial key:  T403
# j:  404
# key:  T404
# j:  405
# key:  T405
# j:  406
# key:  T406
# index:  371 keywords:  arabidopsis
# Word exists in WordNet
# *****************
# j:  406
# initial key:  T406
# j:  407
# key:  T407
# j:  408
# key:  T408
# j:  409
# key:  T409
# index:  372 keywords:  plant cell culture
# Word DOES NOT exists in WordNet
# *****************
# index:  373 keywords:  undifferentiated cells
# Word DOES NOT exists in WordNet
# *****************
# index:  374 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  375 keywords:  heat shock
# Word DOES NOT exists in WordNet
# *****************
# index:  376 keywords:  reticulum associated degradation
# Word DOES NOT exists in WordNet
# *****************
# index:  377 keywords:  shock transcription factors
# Word DOES NOT exists in WordNet
# *****************
# index:  378 keywords:  unfolded protein response
# Word DOES NOT exists in WordNet
# *****************
# index:  379 keywords:  abiotic stress responses
# Word DOES NOT exists in WordNet
# *****************
# index:  380 keywords:  short term exposure
# Word DOES NOT exists in WordNet
# *****************
# index:  381 keywords:  endoplasmic reticulum
# Word DOES NOT exists in WordNet
# *****************
# index:  382 keywords:  gene expression
# Word exists in WordNet
# *****************
# j:  409
# initial key:  T409
# j:  410
# key:  T410
# j:  411
# key:  T411
# j:  412
# key:  T412
# index:  383 keywords:  signaling pathways
# Word DOES NOT exists in WordNet
# *****************
# index:  384 keywords:  quality control
# Word exists in WordNet
# *****************
# j:  412
# initial key:  T412
# j:  413
# key:  T413
# j:  414
# key:  T414
# j:  415
# key:  T415
# index:  385 keywords:  proteome
# Word exists in WordNet
# *****************
# j:  415
# initial key:  T415
# j:  416
# key:  T416
# j:  417
# key:  T417
# j:  418
# key:  T418
# index:  386 keywords:  mass spectrometry
# Word DOES NOT exists in WordNet
# *****************
# index:  387 keywords:  plants
# Word DOES NOT exists in WordNet
# *****************
# index:  388 keywords:  human cells
# Word DOES NOT exists in WordNet
# *****************
# index:  389 keywords:  tissue engineering
# Word DOES NOT exists in WordNet
# *****************
# index:  390 keywords:  cancer
# Word exists in WordNet
# *****************
# j:  418
# initial key:  T418
# j:  419
# key:  T419
# j:  420
# key:  T420
# j:  421
# key:  T421
# index:  391 keywords:  thyroid cancer cells
# Word DOES NOT exists in WordNet
# *****************
# index:  392 keywords:  differential gene expression
# Word DOES NOT exists in WordNet
# *****************
# index:  393 keywords:  arabidopsis thaliana callus
# Word DOES NOT exists in WordNet
# *****************
# index:  394 keywords:  altered gravity conditions
# Word DOES NOT exists in WordNet
# *****************
# index:  395 keywords:  sativa l. seedlings
# Word DOES NOT exists in WordNet
# *****************
# index:  396 keywords:  spheroid formation
# Word DOES NOT exists in WordNet
# *****************
# index:  397 keywords:  endothelial cells
# Word DOES NOT exists in WordNet
# *****************
# index:  398 keywords:  simulated microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  399 keywords:  3 dimensional growth
# Word DOES NOT exists in WordNet
# *****************
# index:  400 keywords:  human chondrocytes
# Word DOES NOT exists in WordNet
# *****************
# index:  401 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  402 keywords:  bacterial adaptation
# Word DOES NOT exists in WordNet
# *****************
# index:  403 keywords:  built environment microbiome
# Word DOES NOT exists in WordNet
# *****************
# index:  404 keywords:  pangenome
# Word DOES NOT exists in WordNet
# *****************
# index:  405 keywords:  bacillus cereus
# Word DOES NOT exists in WordNet
# *****************
# index:  406 keywords:  biofilm formation
# Word DOES NOT exists in WordNet
# *****************
# index:  407 keywords:  staphylococcus aureus
# Word DOES NOT exists in WordNet
# *****************
# index:  408 keywords:  antibiotic resistance
# Word DOES NOT exists in WordNet
# *****************
# index:  409 keywords:  pan genome
# Word DOES NOT exists in WordNet
# *****************
# index:  410 keywords:  evolution
# Word exists in WordNet
# *****************
# j:  421
# initial key:  T421
# j:  422
# key:  T422
# j:  423
# key:  T423
# j:  424
# key:  T424
# index:  411 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  412 keywords:  expression
# Word exists in WordNet
# *****************
# j:  424
# initial key:  T424
# j:  425
# key:  T425
# j:  426
# key:  T426
# j:  427
# key:  T427
# index:  413 keywords:  habitats
# Word DOES NOT exists in WordNet
# *****************
# index:  414 keywords:  bacteria
# Word exists in WordNet
# *****************
# j:  427
# initial key:  T427
# j:  428
# key:  T428
# j:  429
# key:  T429
# j:  430
# key:  T430
# index:  415 keywords:  brain
# Word exists in WordNet
# *****************
# j:  430
# initial key:  T430
# j:  431
# key:  T431
# j:  432
# key:  T432
# j:  433
# key:  T433
# index:  416 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  433
# initial key:  T433
# j:  434
# key:  T434
# j:  435
# key:  T435
# j:  436
# key:  T436
# index:  417 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  418 keywords:  proteomics
# Word exists in WordNet
# *****************
# j:  436
# initial key:  T436
# j:  437
# key:  T437
# j:  438
# key:  T438
# j:  439
# key:  T439
# index:  419 keywords:  2',3' cyclic nucleotide 3' phosphodiesterase
# Word DOES NOT exists in WordNet
# *****************
# index:  420 keywords:  alzheimers disease
# Word DOES NOT exists in WordNet
# *****************
# index:  421 keywords:  dynamin isoforms
# Word DOES NOT exists in WordNet
# *****************
# index:  422 keywords:  cholesterol acyltransferase 1
# Word DOES NOT exists in WordNet
# *****************
# ...
# *****************
# index:  989 keywords:  sax j1808.4 3658
# Word DOES NOT exists in WordNet
# *****************
# index:  990 keywords:  orbital evolution
# Word DOES NOT exists in WordNet
# *****************
# index:  991 keywords:  igr j00291+5934
# Word DOES NOT exists in WordNet
# *****************
# index:  992 keywords:  timing properties
# Word DOES NOT exists in WordNet
# *****************
# index:  993 keywords:  spin
# Word exists in WordNet
# *****************
# j:  1027
# initial key:  T1027
# j:  1028
# key:  T1028
# j:  1029
# key:  T1029
# j:  1030
# key:  T1030
# index:  994 keywords:  discovery
# Word exists in WordNet
# *****************
# j:  1030
# initial key:  T1030
# j:  1031
# key:  T1031
# j:  1032
# key:  T1032
# j:  1033
# key:  T1033
# index:  995 keywords:  space shuttle
# Word exists in WordNet
# *****************
# j:  1033
# initial key:  T1033
# j:  1034
# key:  T1034
# j:  1035
# key:  T1035
# j:  1036
# key:  T1036
# index:  996 keywords:  oxygen
# Word exists in WordNet
# *****************
# j:  1036
# initial key:  T1036
# j:  1037
# key:  T1037
# j:  1038
# key:  T1038
# j:  1039
# key:  T1039
# index:  997 keywords:  carbon dioxide
# Word exists in WordNet
# *****************
# j:  1039
# initial key:  T1039
# j:  1040
# key:  T1040
# j:  1041
# key:  T1041
# j:  1042
# key:  T1042
# index:  998 keywords:  extravehicular activity
# Word DOES NOT exists in WordNet
# *****************
# index:  999 keywords:  astronauts
# Word DOES NOT exists in WordNet
# *****************
# index:  1000 keywords:  space adaptation
# Word DOES NOT exists in WordNet
# *****************
# index:  1001 keywords:  decompression sickness
# Word exists in WordNet
# *****************
# j:  1042
# initial key:  T1042
# j:  1043
# key:  T1043
# j:  1044
# key:  T1044
# j:  1045
# key:  T1045
# index:  1002 keywords:  adaptation
# Word exists in WordNet
# *****************
# j:  1045
# initial key:  T1045
# j:  1046
# key:  T1046
# j:  1047
# key:  T1047
# j:  1048
# key:  T1048
# index:  1003 keywords:  gender
# Word exists in WordNet
# *****************
# j:  1048
# initial key:  T1048
# j:  1049
# key:  T1049
# j:  1050
# key:  T1050
# j:  1051
# key:  T1051
# index:  1004 keywords:  sex
# Word exists in WordNet
# *****************
# j:  1051
# initial key:  T1051
# j:  1052
# key:  T1052
# j:  1053
# key:  T1053
# j:  1054
# key:  T1054
# index:  1005 keywords:  exploration
# Word exists in WordNet
# *****************
# j:  1054
# initial key:  T1054
# j:  1055
# key:  T1055
# j:  1056
# key:  T1056
# j:  1057
# key:  T1057
# index:  1006 keywords:  functional performance
# Word DOES NOT exists in WordNet
# *****************
# index:  1007 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  1057
# initial key:  T1057
# j:  1058
# key:  T1058
# j:  1059
# key:  T1059
# j:  1060
# key:  T1060
# index:  1008 keywords:  bed rest
# Word exists in WordNet
# *****************
# j:  1060
# initial key:  T1060
# j:  1061
# key:  T1061
# j:  1062
# key:  T1062
# j:  1063
# key:  T1063
# index:  1009 keywords:  sensorimotor
# Word exists in WordNet
# *****************
# j:  1063
# initial key:  T1063
# j:  1064
# key:  T1064
# j:  1065
# key:  T1065
# index:  1010 keywords:  countermeasure
# Word exists in WordNet
# *****************
# j:  1065
# initial key:  T1065
# j:  1066
# key:  T1066
# j:  1067
# key:  T1067
# j:  1068
# key:  T1068
# index:  1011 keywords:  duration space flight
# Word DOES NOT exists in WordNet
# *****************
# index:  1012 keywords:  spatial orientation
# Word DOES NOT exists in WordNet
# *****************
# index:  1013 keywords:  treadmill walking
# Word DOES NOT exists in WordNet
# *****************
# index:  1014 keywords:  recovery
# Word exists in WordNet
# *****************
# j:  1068
# initial key:  T1068
# j:  1069
# key:  T1069
# j:  1070
# key:  T1070
# j:  1071
# key:  T1071
# index:  1015 keywords:  strategies
# Word DOES NOT exists in WordNet
# *****************
# index:  1016 keywords:  fall
# Word exists in WordNet
# *****************
# j:  1071
# initial key:  T1071
# j:  1072
# key:  T1072
# j:  1073
# key:  T1073
# j:  1074
# key:  T1074
# index:  1017 keywords:  functional tests
# Word DOES NOT exists in WordNet
# *****************
# index:  1018 keywords:  body unloading
# Word DOES NOT exists in WordNet
# *****************
# index:  1019 keywords:  exercise countermeasures
# Word DOES NOT exists in WordNet
# *****************
# index:  1020 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  1021 keywords:  bed rest
# Word exists in WordNet
# *****************
# j:  1074
# initial key:  T1074
# j:  1075
# key:  T1075
# j:  1076
# key:  T1076
# j:  1077
# key:  T1077
# index:  1022 keywords:  spaceflight
# Word exists in WordNet
# *****************
# j:  1077
# initial key:  T1077
# j:  1078
# key:  T1078
# j:  1079
# key:  T1079
# j:  1080
# key:  T1080
# index:  1023 keywords:  long duration spaceflight
# Word DOES NOT exists in WordNet
# *****************
# index:  1024 keywords:  neuromuscular activation patterns
# Word DOES NOT exists in WordNet
# *****************
# index:  1025 keywords:  vestibular nucleus neurons
# Word DOES NOT exists in WordNet
# *****************
# index:  1026 keywords:  simple aiming task
# Word DOES NOT exists in WordNet
# *****************
# index:  1027 keywords:  space flight
# Word DOES NOT exists in WordNet
# *****************
# index:  1028 keywords:  orthostatic intolerance
# Word DOES NOT exists in WordNet
# *****************
# index:  1029 keywords:  treadmill walking
# Word DOES NOT exists in WordNet
# *****************
# index:  1030 keywords:  skeletal muscle
# Word exists in WordNet
# *****************
# j:  1080
# initial key:  T1080
# j:  1081
# key:  T1081
# j:  1082
# key:  T1082
# j:  1083
# key:  T1083
# index:  1031 keywords:  term spaceflight
# Word DOES NOT exists in WordNet
# *****************
# index:  1032 keywords:  balance control
# Word DOES NOT exists in WordNet
# *****************
# index:  1033 keywords:  gamma rays: general
# Word DOES NOT exists in WordNet
# *****************
# index:  1034 keywords:  gravitational waves
# Word DOES NOT exists in WordNet
# *****************
# index:  1035 keywords:  methods: observational
# Word DOES NOT exists in WordNet
# *****************
# index:  1036 keywords:  neutron star mergers
# Word DOES NOT exists in WordNet
# *****************
# index:  1037 keywords:  bursts
# Word DOES NOT exists in WordNet
# *****************
# index:  1038 keywords:  signatures
# Word DOES NOT exists in WordNet
# *****************
# index:  1039 keywords:  emission
# Word exists in WordNet
# *****************
# j:  1083
# initial key:  T1083
# j:  1084
# key:  T1084
# j:  1085
# key:  T1085
# j:  1086
# key:  T1086
# index:  1040 keywords:  accretion
# Word exists in WordNet
# *****************
# j:  1086
# initial key:  T1086
# j:  1087
# key:  T1087
# j:  1088
# key:  T1088
# j:  1089
# key:  T1089
# index:  1041 keywords:  accretion disks
# Word DOES NOT exists in WordNet
# *****************
# index:  1042 keywords:  pulsars: individual (swift j0243.6+6124)
# Word DOES NOT exists in WordNet
# *****************
# index:  1043 keywords:  x rays: binaries
# Word DOES NOT exists in WordNet
# *****************
# index:  1044 keywords:  magnetized neutron stars
# Word DOES NOT exists in WordNet
# *****************
# index:  1045 keywords:  ngc 7793 p13
# Word DOES NOT exists in WordNet
# *****************
# index:  1046 keywords:  timing explorer
# Word DOES NOT exists in WordNet
# *****************
# index:  1047 keywords:  accretion luminosity
# Word DOES NOT exists in WordNet
# *****************
# index:  1048 keywords:  scattering feature
# Word DOES NOT exists in WordNet
# *****************
# index:  1049 keywords:  binaries
# Word DOES NOT exists in WordNet
# *****************
# index:  1050 keywords:  discovery
# Word exists in WordNet
# *****************
# j:  1089
# initial key:  T1089
# j:  1090
# key:  T1090
# j:  1091
# key:  T1091
# j:  1092
# key:  T1092
# index:  1051 keywords:  fields
# Word exists in WordNet
# *****************
# j:  1092
# initial key:  T1092
# j:  1093
# key:  T1093
# j:  1094
# key:  T1094
# index:  1052 keywords:  line
# Word exists in WordNet
# *****************
# j:  1094
# initial key:  T1094
# j:  1095
# key:  T1095
# j:  1096
# key:  T1096
# j:  1097
# key:  T1097
# index:  1053 keywords:  outbursts
# Word DOES NOT exists in WordNet
# *****************
# index:  1054 keywords:  gamma ray burst: individual (grb 170817a)
# Word DOES NOT exists in WordNet
# *****************
# index:  1055 keywords:  gravitational waves
# Word DOES NOT exists in WordNet
# *****************
# index:  1056 keywords:  methods: observational
# Word DOES NOT exists in WordNet
# *****************
# index:  1057 keywords:  slit camera gsc
# Word DOES NOT exists in WordNet
# *****************
# index:  1058 keywords:  ray
# Word exists in WordNet
# *****************
# j:  1097
# initial key:  T1097
# j:  1098
# key:  T1098
# j:  1099
# key:  T1099
# j:  1100
# key:  T1100
# index:  1059 keywords:  space radiation protection
# Word DOES NOT exists in WordNet
# *****************
# index:  1060 keywords:  shielding spacesuit
# Word DOES NOT exists in WordNet
# *****************
# index:  1061 keywords:  resource optimization
# Word DOES NOT exists in WordNet
# *****************
# index:  1062 keywords:  solar particle events
# Word DOES NOT exists in WordNet
# *****************
# index:  1063 keywords:  interplanetary missions
# Word DOES NOT exists in WordNet
# *****************
# index:  1064 keywords:  international space station
# Word DOES NOT exists in WordNet
# *****************
# index:  1065 keywords:  proton event fluences
# Word DOES NOT exists in WordNet
# *****************
# index:  1066 keywords:  low earth orbit
# Word DOES NOT exists in WordNet
# *****************
# index:  1067 keywords:  space radiation
# Word DOES NOT exists in WordNet
# *****************
# index:  1068 keywords:  probability model
# Word DOES NOT exists in WordNet
# *****************
# index:  1069 keywords:  environment
# Word exists in WordNet
# *****************
# j:  1100
# initial key:  T1100
# j:  1101
# key:  T1101
# j:  1102
# key:  T1102
# j:  1103
# key:  T1103
# index:  1070 keywords:  simulation
# Word exists in WordNet
# *****************
# j:  1103
# initial key:  T1103
# j:  1104
# key:  T1104
# j:  1105
# key:  T1105
# j:  1106
# key:  T1106
# index:  1071 keywords:  physics
# Word exists in WordNet
# *****************
# j:  1106
# initial key:  T1106
# j:  1107
# key:  T1107
# j:  1108
# key:  T1108
# j:  1109
# key:  T1109
# index:  1072 keywords:  design
# Word exists in WordNet
# *****************
# j:  1109
# initial key:  T1109
# j:  1110
# key:  T1110
# j:  1111
# key:  T1111
# j:  1112
# key:  T1112
# index:  1073 keywords:  shield
# Word exists in WordNet
# *****************
# j:  1112
# initial key:  T1112
# j:  1113
# key:  T1113
# j:  1114
# key:  T1114
# j:  1115
# key:  T1115
# index:  1074 keywords:  auxin efflux carrier
# Word DOES NOT exists in WordNet
# *****************
# index:  1075 keywords:  fixatives
# Word DOES NOT exists in WordNet
# *****************
# index:  1076 keywords:  immunohistochemistry
# Word exists in WordNet
# *****************
# j:  1115
# initial key:  T1115
# j:  1116
# key:  T1116
# j:  1117
# key:  T1117
# j:  1118
# key:  T1118
# index:  1077 keywords:  pisum sativum
# Word exists in WordNet
# *****************
# j:  1118
# initial key:  T1118
# j:  1119
# key:  T1119
# j:  1120
# key:  T1120
# j:  1121
# key:  T1121
# index:  1078 keywords:  space experiment
# Word DOES NOT exists in WordNet
# *****************
# index:  1079 keywords:  zea mays
# Word exists in WordNet
# *****************
# j:  1121
# initial key:  T1121
# j:  1122
# key:  T1122
# j:  1123
# key:  T1123
# j:  1124
# key:  T1124
# index:  1080 keywords:  etiolated pea seedlings
# Word DOES NOT exists in WordNet
# *****************
# index:  1081 keywords:  early growth stage
# Word DOES NOT exists in WordNet
# *****************
# index:  1082 keywords:  cucumber seedlings
# Word DOES NOT exists in WordNet
# *****************
# index:  1083 keywords:  microgravity conditions
# Word DOES NOT exists in WordNet
# *****************
# index:  1084 keywords:  cytochemical localization
# Word DOES NOT exists in WordNet
# *****************
# index:  1085 keywords:  3 dimensional clinostat
# Word DOES NOT exists in WordNet
# *****************
# index:  1086 keywords:  gravitropic response
# Word DOES NOT exists in WordNet
# *****************
# index:  1087 keywords:  space
# Word exists in WordNet
# *****************
# j:  1124
# initial key:  T1124
# j:  1125
# key:  T1125
# j:  1126
# key:  T1126
# j:  1127
# key:  T1127
# index:  1088 keywords:  plants
# Word DOES NOT exists in WordNet
# *****************
# index:  1089 keywords:  morphogenesis
# Word exists in WordNet
# *****************
# j:  1127
# initial key:  T1127
# j:  1128
# key:  T1128
# j:  1129
# key:  T1129
# j:  1130
# key:  T1130
# index:  1090 keywords:  local extinction
# Word DOES NOT exists in WordNet
# *****************
# index:  1091 keywords:  pulsating diffusion flame
# Word DOES NOT exists in WordNet
# *****************
# index:  1092 keywords:  microgravity droplet combustion
# Word DOES NOT exists in WordNet
# *****************
# index:  1093 keywords:  negative temperature coefficient
# Word DOES NOT exists in WordNet
# *****************
# index:  1094 keywords:  cool flame
# Word DOES NOT exists in WordNet
# *****************
# index:  1095 keywords:  n heptane
# Word DOES NOT exists in WordNet
# *****************
# index:  1096 keywords:  droplet combustion
# Word DOES NOT exists in WordNet
# *****************
# index:  1097 keywords:  radiation
# Word exists in WordNet
# *****************
# j:  1130
# initial key:  T1130
# j:  1131
# key:  T1131
# j:  1132
# key:  T1132
# j:  1133
# key:  T1133
# index:  1098 keywords:  dosimetry
# Word exists in WordNet
# *****************
# j:  1133
# initial key:  T1133
# j:  1134
# key:  T1134
# j:  1135
# key:  T1135
# j:  1136
# key:  T1136
# index:  1099 keywords:  acoustic waves
# Word DOES NOT exists in WordNet
# *****************
# index:  1100 keywords:  deprived areas
# Word DOES NOT exists in WordNet
# *****************
# index:  1101 keywords:  global south
# Word DOES NOT exists in WordNet
# *****************
# index:  1102 keywords:  international space station (iss) nighttime light (ntl) images
# Word DOES NOT exists in WordNet
# *****************
# index:  1103 keywords:  slums
# Word DOES NOT exists in WordNet
# *****************
# index:  1104 keywords:  urban remote sensing
# Word DOES NOT exists in WordNet
# *****************
# index:  1105 keywords:  satellite imagery
# Word DOES NOT exists in WordNet
# *****************
# index:  1106 keywords:  china
# Word exists in WordNet
# *****************
# j:  1136
# initial key:  T1136
# j:  1137
# key:  T1137
# j:  1138
# key:  T1138
# index:  1107 keywords:  dmsp
# Word DOES NOT exists in WordNet
# *****************
# index:  1108 keywords:  flame spread
# Word DOES NOT exists in WordNet
# *****************
# index:  1109 keywords:  droplet cloud
# Word DOES NOT exists in WordNet
# *****************
# index:  1110 keywords:  group combustion
# Word DOES NOT exists in WordNet
# *****************
# index:  1111 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  1112 keywords:  combustion experiments aboard
# Word DOES NOT exists in WordNet
# *****************
# index:  1113 keywords:  fuel
# Word exists in WordNet
# *****************
# j:  1138
# initial key:  T1138
# j:  1139
# key:  T1139
# j:  1140
# key:  T1140
# j:  1141
# key:  T1141
# index:  1114 keywords:  arrays
# Word DOES NOT exists in WordNet
# *****************
# index:  1115 keywords:  propagation
# Word exists in WordNet
# *****************
# j:  1141
# initial key:  T1141
# j:  1142
# key:  T1142
# j:  1143
# key:  T1143
# j:  1144
# key:  T1144
# index:  1116 keywords:  generation
# Word exists in WordNet
# *****************
# j:  1144
# initial key:  T1144
# j:  1145
# key:  T1145
# j:  1146
# key:  T1146
# j:  1147
# key:  T1147
# index:  1117 keywords:  spray
# Word exists in WordNet
# *****************
# j:  1147
# initial key:  T1147
# j:  1148
# key:  T1148
# j:  1149
# key:  T1149
# j:  1150
# key:  T1150
# index:  1118 keywords:  droplet combustion
# Word DOES NOT exists in WordNet
# *****************
# index:  1119 keywords:  radiative extinction
# Word DOES NOT exists in WordNet
# *****************
# index:  1120 keywords:  n alkanes
# Word DOES NOT exists in WordNet
# *****************
# index:  1121 keywords:  microgravity
# Word DOES NOT exists in WordNet
# *****************
# index:  1122 keywords:  spherical diffusion flames
# Word DOES NOT exists in WordNet
# *****************
# index:  1123 keywords:  cool flames
# Word DOES NOT exists in WordNet
# *****************
# index:  1124 keywords:  combustion
# Word exists in WordNet
# *****************
# j:  1150
# initial key:  T1150
# j:  1151
# key:  T1151
# j:  1152
# key:  T1152
# j:  1153
# key:  T1153
# index:  1125 keywords:  heptane
# Word exists in WordNet
# *****************
# j:  1153
# initial key:  T1153
# j:  1154
# key:  T1154
# j:  1155
# key:  T1155
# j:  1156
# key:  T1156

# %%
df_topic.head(10)
# Out:
#    key     type                                        topic_title  \
# 0   T1    topic  Two regimes of a single n-heptane droplet comb...
# 1   T2    topic                                         combustion
# 2   T3  cluster                                          oxidation
# 3   T4    topic  Two regimes of a single n-heptane droplet comb...
# 4   T5    topic                                            droplet
# 5   T6  cluster                                               drop
# 6   T7    topic  Two regimes of a single n-heptane droplet comb...
# 7   T8    topic                                          diffusion
# 8   T9  cluster                                    natural_process
# 9  T10    topic  Desert cyanobacteria under space and planetary...
#
#                                           definition reference  wordnet_ID
# 0                                         combustion            13450206-n
# 1  a process in which a substance reacts with oxy...            13450206-n
# 2  the process of oxidizing; the addition of oxyg...            13530408-n
# 3                                            droplet            13771828-n
# 4                                        a tiny drop            13771828-n
# 5                a shape that is spherical and small            13901585-n
# 6                                          diffusion            13465530-n
# 7  (physics) the process in which there is moveme...            13465530-n
# 8  a process existing in or produced by nature (r...            13518963-n
# 9                                       life_support            03664159-n

# %%
df_topic[df_topic['type'] == 'cluster'].shape[0]
# Out:
# 379

# %%
df_topic[df_topic['key'] == 'T264']
# Out:
#       key   type topic_title  \
# 263  T264  topic  perception
#
#                                             definition reference  wordnet_ID
# 263  the representation of what is perceived; basic...            05930136-n

# %%
df_topic[df_topic['definition'].str.contains('^ab', regex=True)]
# Out:
#       key   type                                        topic_title  \
# 35    T36  topic  Photolysis of Cometary Organic Dust Analogs on...
# 190  T191  topic  The 11 yr of low activity of the magnetar XTE ...
# 223  T224  topic  3D Printing in Zero G Technology Demonstration...
# 720  T721  topic  X-Ray, Optical, and Near-infrared Monitoring o...
#
#      definition reference  wordnet_ID
# 35   absorption            13423922-n
# 190  absorption            13423922-n
# 223         abs            14592028-n
# 720  absorption            13423922-n

# %%
df_topic[df_topic['key'] == 'T204']
# Out:
#       key   type  topic_title                               definition  \
# 203  T204  topic  spaceflight  a voyage outside the Earth's atmosphere
#
#     reference  wordnet_ID
# 203            00313502-n

# %%
df_topic[df_topic['topic_title'].str.contains('device', regex=True)]
# Out:
#       key     type topic_title  \
# 176  T177    topic     devices
# 359  T360  cluster      device
# 782  T783  cluster      device
#
#                                             definition reference  wordnet_ID
# 176  an inclination or desire; used in the plural i...            06198876-n
# 359  an instrumentality invented for a particular p...            03183080-n
# 782  an instrumentality invented for a particular p...            03183080-n

# %%
df_topic[df_topic['key'].isin(['T176','T177', 'T178'])]
# Out:
#       key     type                                        topic_title  \
# 175  T176    topic  Chemiluminescence-based biosensor for monitori...
# 176  T177    topic                                            devices
# 177  T178  cluster                                        inclination
#
#                                             definition reference  wordnet_ID
# 175                                            devices            06198876-n
# 176  an inclination or desire; used in the plural i...            06198876-n
# 177  an attitude of mind especially one that favors...            06196584-n

# %%
df_topic[df_topic['key'].isin(['T358','T359', 'T360'])]
# Out:
#       key     type                                        topic_title  \
# 357  T358    topic  Towards Understanding the Origin of Cosmic-Ray...
# 358  T359    topic                                           detector
# 359  T360  cluster                                             device
#
#                                             definition reference  wordnet_ID
# 357                                           detector            03180969-n
# 358  any device that receives a signal or stimulus ...            03180969-n
# 359  an instrumentality invented for a particular p...            03183080-n

# %%
df_topic[df_topic['key'].isin(['T781','T782', 'T783'])]
# Out:
#       key     type                                        topic_title  \
# 780  T781    topic  REMOTE ECHOGRAPHY BETWEEN A GROUND CONTROL CEN...
# 781  T782    topic                                     remote_control
# 782  T783  cluster                                             device
#
#                                             definition reference  wordnet_ID
# 780                                     remote_control            04074963-n
# 781  a device that can be used to control a machine...            04074963-n
# 782  an instrumentality invented for a particular p...            03183080-n

# %%
# df_topic.to_csv('20200122_df_topic.csv', index=None)

# %%
list_of_duplicated_topic_titles = \
df_topic[(df_topic.duplicated('topic_title')) 
         & (df_topic['type'] == 'cluster')
#          & (df_topic['topic_title'].str.contains('^device', regex=True))
        ]['topic_title'].values.tolist()

# %%
# list_of_duplicated_topic_titles

# %%
df_topic[(df_topic['topic_title'].str.contains('device'))]
# Out:
#       key     type topic_title  \
# 176  T177    topic     devices
# 359  T360  cluster      device
# 782  T783  cluster      device
#
#                                             definition reference  wordnet_ID
# 176  an inclination or desire; used in the plural i...            06198876-n
# 359  an instrumentality invented for a particular p...            03183080-n
# 782  an instrumentality invented for a particular p...            03183080-n

# %%
df_topic[df_topic['topic_title'].str.contains('measurement')]
# Out:
#         key     type  topic_title  \
# 1019  T1020  cluster  measurement
# 1134  T1135  cluster  measurement
#
#                                              definition reference  wordnet_ID
# 1019  the act or process of assigning numbers to phe...            00996969-n
# 1134  the act or process of assigning numbers to phe...            00996969-n
